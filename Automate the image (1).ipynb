# %%
from PIL import Image
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Image Processing'

# %%
image1 = Image.open("bridge.jpg")

image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x721 at 0x1D32A1EF7C0>

# %%
image1.show()

# %%
#Changing File type (Extension)
image1.save("bridge.png")

# %%
# lists all the files and folders in the current working directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'apple.jfif',
#  'arithmetic operation.ipynb',
#  'Automate the image.ipynb',
#  'bitwise operation.ipynb',
#  'bridge.jpg',
#  'bridge.png',
#  'butterfly.png',
#  'canvas program.ipynb',
#  'Capture.PNG',
#  'cat.png',
#  'cat_damaged.png',
#  'cat_inpainted.png',
#  'cat_mask.png',
#  'contors.ipynb',
#  'conversion.ipynb',
#  'crop.png',
#  'cup.jpg',
#  'dam.png',
#  'damage.jpg',
#  'di.jpg',
#  'dice.png',
#  'dice1.png',
#  'dice5.jpg',
#  'display img.ipynb',
#  'face.jpg',
#  'fame1.jpg',
#  'flower.jpg',
#  'flower1.jpg',
#  'flower2.jpg',
#  'flower2.tiff',
#  'flower3.jpg',
#  'horse.png',
#  'house.jpg',
#  'im.jpg',
#  'im1.jpg',
#  'image manipulation.ipynb',
#  'image negative.ipynb',
#  'image restoration.ipynb',
#  'Image restoration.py',
#  'image.png',
#  'images',
#  'Interpolation.ipynb',
#  'kk.png',
#  'logimg.jpg',
#  'logo.png',
#  'logo1.jpg',
#  'logo2.webp',
#  'mango.jfif',
#  'mask.png',
#  'masking program.ipynb',
#  'my.jpg',
#  'my.png',
#  'nature.jpg',
#  'nois.jpg',
#  'noise program.ipynb',
#  'operation on image.ipynb',
#  'path.ipynb',
#  'pil_grayscale.png',
#  'read various library.ipynb',
#  'resizedBeach1.jpg',
#  'result.jpg',
#  'rotate_output.jpg',
#  'sampling & quantization.ipynb',
#  'samplingandquantization.ipynb',
#  'sci.jpg',
#  'skimage_gray.png',
#  'street.jpg',
#  'test_image_altered_background.jpg',
#  'text_removed_image.jpg',
#  'train.jpg',
#  'trial.ipynb',
#  'Untitled.ipynb',
#  'ut.jpg',
#  'watermark.jpg']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# bridge & .jpg
# cup & .jpg
# damage & .jpg
# di & .jpg
# dice5 & .jpg
# face & .jpg
# fame1 & .jpg
# flower & .jpg
# flower1 & .jpg
# flower2 & .jpg
# flower3 & .jpg
# house & .jpg
# im & .jpg
# im1 & .jpg
# logimg & .jpg
# logo1 & .jpg
# my & .jpg
# nature & .jpg
# nois & .jpg
# resizedBeach1 & .jpg
# result & .jpg
# rotate_output & .jpg
# sci & .jpg
# street & .jpg
# test_image_altered_background & .jpg
# text_removed_image & .jpg
# train & .jpg
# ut & .jpg
# watermark & .jpg

# %%
#Looping over the image files
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# bridge.jpg
# cup.jpg
# damage.jpg
# di.jpg
# dice5.jpg
# face.jpg
# fame1.jpg
# flower.jpg
# flower1.jpg
# flower2.jpg
# flower3.jpg
# house.jpg
# im.jpg
# im1.jpg
# logimg.jpg
# logo1.jpg
# my.jpg
# nature.jpg
# nois.jpg
# resizedBeach1.jpg
# result.jpg
# rotate_output.jpg
# sci.jpg
# street.jpg
# test_image_altered_background.jpg
# text_removed_image.jpg
# train.jpg
# ut.jpg
# watermark.jpg

# %%
# Creating new Directory using OS library
os.mkdir('NewExtnsn')
# Note: If you already have a directory with this name, you will get error.
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.save("NewExtnsn/{}.pdf".format(fn))
        #look into NewExtnsn directory

# %%
# Creating new multiple Directories using OS library
os.makedirs('resize//small')
os.makedirs('resize//tiny')
# Note: If you already have a directory with this name, you will get error.
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))
        #look into resize//small and resize//tiny directory

# %%
#Converting to Black and White
image2 = Image.open("bridge.jpg")
image2 = image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=1080x721 at 0x1D32A1E4CD0>

# %%
# Creating new Directory using OS library
os.mkdir('b&w')
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.convert(mode = 'L')
        im.save("b&w/{}_bw.{}".format(fn, fext))
        #look into b&w directory

# %%
#Rotating the Images
#rotating the image to 55 Degree angle
image3 = Image.open("flower3.jpg")
image3.rotate(55).save("image3.jpg")
Image3 = Image.open("image3.jpg")
Image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1D32A3E1A00>

# %%
# Creating new Directory using OS library
os.mkdir('rotate')
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        im = i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
        #look into rotate directory
