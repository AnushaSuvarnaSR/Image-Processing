# %%
# import the modules
import os
from os import listdir

# get the path/directory
folder_dir = "D:\png images"
for images in os.listdir(folder_dir):

	# check if the image ends with png
	if (images.endswith(".png")):
		print(images)
# Out:
# flowee.png
# star.png
# wing.png

# %%
# import the modules
import os
from os import listdir

# get the path or directory
folder_dir = "D:\images"
for images in os.listdir(folder_dir):

	# check if the image ends with png or jpg or jpeg
	if (images.endswith(".png") or images.endswith(".jpg")\
		or images.endswith(".jpeg") or images.endswith(".jfif")or images.endswith(".webp")):
		# display
		print(images)
# Out:
# apple.jfif
# apple.jpg
# cat.jpg
# cat.png
# download.jpg
# flowee.png
# flower.jpg
# low.webp
# mango.jfif
# scene.jpg
# star.png
# wing.png

# %%
#import necessary packages
import cv2
import imageio
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
 
#Set the path where images are stored
img_dir = "D:/images/" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*g')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = plt.imread(f1)
    data.append(img)
    imgresize=cv2.resize(img,(250,250))
    #cv2.imshow('image',imgresize)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    plt.figure()
    plt.imshow(imgresize)

# %%
#import necessary packages
import cv2
import imageio
import os
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)
 
#Set the path where images are stored
img_dir = "D:/images/" # Enter Directory of all images  
data_path = os.path.join(img_dir,'*')
files = glob.glob(data_path)
data = []
for f1 in files:
    img = cv2.imread(f1,0)
    data.append(img)
    plt.figure()
    plt.imshow(img,cmap='gray')
